# %% [markdown]
# ## Summarization

# %%
import numpy as np
import pandas as pd

# %%
tweet_2020_1 = pd.read_csv('tweet_2020_1.csv') 
tweet_2020_2 = pd.read_csv('tweet_2020_2.csv')  
tweet_2020_3 = pd.read_csv('tweet_2020_3.csv')  
tweet_2020_4 = pd.read_csv('tweet_2020_4.csv')  
tweet_2020_5 = pd.read_csv('tweet_2020_5.csv')  
tweet_2020_6 = pd.read_csv('tweet_2020_6.csv')  
tweet_2020_7 = pd.read_csv('tweet_2020_7.csv')  
tweet_2020_8 = pd.read_csv('tweet_2020_8.csv')  
tweet_2020_9 = pd.read_csv('tweet_2020_9.csv')
tweet_2020_10 = pd.read_csv('tweet_2020_10.csv')

# %%
#tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ').loc[:, ['text', 'timestamp']]

# %%
summar = []
time = []

# %% [markdown]
# Cluster 1

# %%
#в основном ставят перед фактом и переживают за Австралию
summar.append(list(tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[4])
time.append(list(tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[4])

# %%
#кластер в котором просят помощь
list(tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])
# Out:
# ['  can you please help. A country that you love is on fire and needs help  ',
#  'Please help to spread more awareness about this. Australia is BURNING and we need to help! ',
#  'Please help me save my country if you can donate or even just share we need your help    ',
#  'Australia needs your help. Below will be links on how you can help   ',
#  'Hers how you can help no matter where in the world you are. Please help      …',
#  'Please donate and give this great organisation help so they can help those in need    ',
#  ' please help us get the rest of the worlds attention Australia is on fire. We need help.   ',
#  'Knowing Australia is burning and billions of animals have died and many people and hundreds of house lost it makes me want to help but I can’t help just myself and I don’t know how to please how can I help and please can other people help  ',
#  ' - can you help spread the word that Australia needs our help? ',
# ...

# %%
#кластер про 500 миллионов смертей животных
summar.append(list(tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])[0])
time.append(list(tweet_2020_1.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['timestamp'])[0])

# %% [markdown]
# Cluster 2

# %%
#кластер про смерти животных и людей, есть еще информация
summar.append(list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[5])
time.append(list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[5])
summar.append(list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[9])
time.append(list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[9])

# %%
#pray cluster
#list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#help - please кластер
#list(tweet_2020_2.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 3

# %%
#PLeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeease
#list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])

# %%
summar.append(list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[6])
time.append(list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[6])

# %%
summar.append(list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[34])
time.append(list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[34])

# %%
#pray cluster
#list(tweet_2020_3.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 4

# %%
#pray
#list(tweet_2020_4.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#please cluster
#list(tweet_2020_4.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])

# %%
summar.append(list(tweet_2020_4.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])[5])
time.append(list(tweet_2020_4.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['timestamp'])[5])

# %% [markdown]
# Cluster 5

# %%
summar.append(list(tweet_2020_5.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[3])
time.append(list(tweet_2020_5.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[3])

# %%
#pray again
#list(tweet_2020_5.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#please
#list(tweet_2020_5.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 6

# %%
summar.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[0])
time.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[0])
summar.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[2])
time.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[2])

# %%
summar.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[0])
time.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[0])
summar.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[50])
time.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[50])
summar.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[100])
time.append(list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[100])

# %%
#classic please
#list(tweet_2020_6.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 7

# %%
#thank you / donat cluster
#list(tweet_2020_7.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#please help cluster
#list(tweet_2020_7.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#climate change cluster
#list(tweet_2020_7.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 8

# %%
#please help cluster
#list(tweet_2020_8.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])

# %%
summar.append(list(tweet_2020_8.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[12])
time.append(list(tweet_2020_8.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[12])

# %%
#climate change
#list(tweet_2020_8.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Cluster 9

# %%
#donate
#list(tweet_2020_9.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])

# %%
#please donate
#list(tweet_2020_9.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])

# %%
summar.append(list(tweet_2020_9.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])[0])
time.append(list(tweet_2020_9.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['timestamp'])[0])

# %% [markdown]
# Cluster 10

# %%
summar.append(list(tweet_2020_10.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['text'])[6])
time.append(list(tweet_2020_10.sort_values(by = 'distances').query('cluster_3 == 0 and preprop != "" and preprop_len > 3 ')['timestamp'])[6])

# %%
summar.append(list(tweet_2020_10.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['text'])[0])
time.append(list(tweet_2020_10.sort_values(by = 'distances').query('cluster_3 == 1 and preprop != "" and preprop_len > 3 ')['timestamp'])[0])

# %%
#help
#list(tweet_2020_10.sort_values(by = 'distances').query('cluster_3 == 2 and preprop != "" and preprop_len > 3 ')['text'])

# %% [markdown]
# Summarization

# %%
print(len(summar))
print(len(time))
# Out:
# 17
# 17

# %%
summarize = pd.DataFrame()
summarize['tweet'] = summar
summarize['time'] = time

# %%
for i in (list(summarize.sort_values(by = 'time')['tweet'])):
    print(i, '\n')
# Out:
# Over 500 million animals lives lost
#
# Also the affects of climate change needs to end. Australian wildlife are in danger at this time due to the wildfires. Hoping that people take their time to spread the word that it is real and take action.
#
# NSW fires: The world has made the link between Australian coal, fires and climate  …
#
# Such sad times in   The Australian fires have burned 6 million hectares of land, 23 people have died and many more missing , half a billion animals are estimated to have died. OnFire My thoughts are with everyone involved.
#
# • 24 people dead• 500M animals dead• 8,000 koalas dead• Over 5.5 million hectares burned • More than 1400 homes destroyed• More than 10 million people in toxic levels of bushfire smoke Please pray for   OnFire Bushfires
#
# Climate change. Half a billion animals have been killed by the bush fires. 15 million acres have burned. 30% of koalas have died. So sad to see Australia like that. Hope it'll stop. Be strong!
#
# ...

# %%
summarize.to_csv('summarize.csv')
